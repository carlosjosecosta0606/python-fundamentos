# %%
import openai

# %%
client = openai.Client()

# %% [markdown]
# ### Fluxo da Conversa
# - User: Usuário que inicia a conversa
# - Assistant: Bot que responda a pergunta

# %%
mensagens = [{"role": "user", "content": "Defina uma laranja em cinco palavras."}]

# %%
resposta = client.chat.completions.create(
    messages=mensagens,
    model="gpt-3.5-turbo-0125",
    max_tokens=1000,
    temperature=0
)

# %%
resposta.choices[0].message.content
# Out:
# 'Fruta cítrica suculenta e saborosa.'

# %%
mensagens.append({"role": "assistant", "content": resposta.choices[0].message.content})

# %%
mensagens.append({"role": "user", "content": "E qual a sua cor?"})

# %%
resposta = client.chat.completions.create(
    messages=mensagens,
    model="gpt-3.5-turbo-0125",
    max_tokens=1000,
    temperature=0
)

# %%
resposta.choices[0].message.content
# Out:
# 'Laranja.'

# %%
mensagens.append({"role": "assistant", "content": resposta.choices[0].message.content})

# %%
mensagens
# Out:
# [{'role': 'user', 'content': 'Defina uma laranja em cinco palavras.'},
#  {'role': 'assistant', 'content': 'Fruta cítrica suculenta e saborosa.'},
#  {'role': 'user', 'content': 'E qual a sua cor?'},
#  {'role': 'assistant', 'content': 'Laranja.'}]

# %% [markdown]
# Utilizando Função

# %%
def geracao_texto(mensagens, model="gpt-3.5-turbo-0125", max_tokens=1000, temperature=0):
    resposta = client.chat.completions.create(
        messages=mensagens,
        model=model,
        max_tokens=max_tokens,
        temperature=temperature
    )
    mensagens.append({"role": "assistant", "content":resposta.choices[0].message.content})
    return mensagens

# %%
msg1 = [{"role": "user", "content": "Defina o que é API em cinco palavras."}]
mensagens = geracao_texto(msg1)

# %%
mensagens
# Out:
# [{'role': 'user', 'content': 'Defina o que é API em cinco palavras.'},
#  {'role': 'assistant', 'content': 'Interface de programação de aplicativos.'}]

# %% [markdown]
# Utilizando Stream

# %%
mensagens = [{"role": "user", "content": "Conte uma história simples e objetiva sobre LLM."}]
resposta = client.chat.completions.create(
    messages=mensagens,
    model="gpt-3.5-turbo-0125",
    max_tokens=1000,
    temperature=0,
    stream=True
)

# %%
resposta

# %%
for resposta_stream in resposta:
    texto = resposta_stream.choices[0].delta.content
    if texto:
        print(texto, end="")
# Out:
# LLM era um jovem estudante de direito muito dedicado e esforçado. Ele sempre se destacava nas aulas e era elogiado pelos professores por sua inteligência e comprometimento.
#
# Um dia, LLM recebeu a notícia de que havia sido selecionado para participar de um renomado programa de intercâmbio em um dos melhores escritórios de advocacia do mundo. Ele ficou radiante com a oportunidade e se dedicou ainda mais aos estudos para aproveitar ao máximo essa experiência.
#
# Durante o intercâmbio, LLM teve a chance de aprender com os melhores profissionais da área e se envolver em casos complexos e desafiadores. Ele se destacou mais uma vez, mostrando todo o seu talento e dedicação.
#
# Ao final do programa, LLM foi convidado para integrar o escritório de advocacia como advogado associado, conquistando assim o reconhecimento e respeito de seus colegas e superiores.
#
# LLM se tornou um advogado de sucesso, sempre buscando a justiça e o bem-estar de seus clientes, e nunca deixando de lado sua humildade e determinação. Ele sabia que o segredo para o sucesso era o esforço e a dedicação, e estava disposto a enfrentar todos os desafios que surgissem em seu caminho.
